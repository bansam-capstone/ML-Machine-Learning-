# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("csv/new_combined_data_labeled.csv")
df_rain = pd.read_csv("csv/new_data_rain.csv")
df_raw = pd.read_csv('csv/weather.csv')

# %% [markdown]
# # COMBINED DATA

# %%
df.corr(numeric_only=True)
# Out:
#                 temperature  humidity  pressure  wind_speed  wind_direction  \
# temperature        1.000000 -0.965514 -0.269504    0.642658       -0.132005
# humidity          -0.965514  1.000000  0.255808   -0.704510        0.111768
# pressure          -0.269504  0.255808  1.000000   -0.283998        0.195888
# wind_speed         0.642658 -0.704510 -0.283998    1.000000       -0.079001
# wind_direction    -0.132005  0.111768  0.195888   -0.079001        1.000000
# rain               0.129102  0.026077 -0.080273   -0.069116        0.032094
# cloudiness         0.015463  0.039550  0.015093   -0.102219       -0.006256
# description        0.100419  0.041455 -0.016465   -0.126695       -0.014270
# condition_type     0.116020  0.030579 -0.052692   -0.086102        0.019349
#
#                     rain  cloudiness  description  condition_type
# temperature     0.129102    0.015463     0.100419        0.116020
# humidity        0.026077    0.039550     0.041455        0.030579
# pressure       -0.080273    0.015093    -0.016465       -0.052692
# wind_speed     -0.069116   -0.102219    -0.126695       -0.086102
# wind_direction  0.032094   -0.006256    -0.014270        0.019349
# rain            1.000000    0.229967     0.762959        0.812015
# cloudiness      0.229967    1.000000     0.475654        0.149962
# description     0.762959    0.475654     1.000000        0.750581
# condition_type  0.812015    0.149962     0.750581        1.000000

# %%
df.head()
# Out:
#    temperature  humidity  pressure  wind_speed  wind_direction  rain  \
# 0        24.38        93      1010        1.54             200   0.0
# 1        24.41        93      1011        1.32             201   0.0
# 2        24.34        92      1010        1.47             207   0.0
# 3        24.31        92      1009        1.53             213   0.0
# 4        23.97        95      1009        1.61             212   0.0
#
#    cloudiness  description  condition_type            timestamp label
# 0          72            0               0  2024-10-25 13:09:08  aman
# 1          55            0               0  2024-10-25 14:09:08  aman
# 2          60            0               0  2024-10-25 15:09:08  aman
# 3          61            0               0  2024-10-25 16:09:08  aman
# 4          59            0               0  2024-10-25 17:09:08  aman

# %%
df_rain.describe()
# Out:
#        temperature    humidity     pressure  wind_speed  wind_direction  \
# count   289.000000  289.000000   289.000000  289.000000      289.000000
# mean     26.677924   85.723183  1008.788927    0.905813      172.761246
# std       3.176765   13.612425     1.720106    0.473229      100.648324
# min      22.420000   48.000000  1005.000000    0.060000        1.000000
# 25%      23.660000   75.000000  1007.000000    0.570000       93.000000
# 50%      26.150000   91.000000  1009.000000    0.840000      159.000000
# 75%      29.410000   97.000000  1010.000000    1.180000      243.000000
# max      34.200000  100.000000  1013.000000    2.360000      360.000000
#
#              rain  cloudiness  description  condition_type
# count  289.000000  289.000000   289.000000           289.0
# mean     0.685606   86.553633     4.477509             1.0
# std      0.573653   19.525217     0.854124             0.0
# min      0.100000    4.000000     4.000000             1.0
# 25%      0.230000   81.000000     4.000000             1.0
# 50%      0.520000   95.000000     4.000000             1.0
# 75%      0.970000  100.000000     4.000000             1.0
# max      2.890000  100.000000     6.000000             1.0

# %%
plt.pie(df['label'].value_counts().tolist(), labels=df['label'].unique().tolist(), colors=['#ff9999', '#66b3ff', '#99ff99'], autopct='%1.1f%%', startangle=90)
# Menambahkan judul
plt.title('Distribution of Categories')

# Menampilkan plot
plt.show()

# %%
plt.scatter(df['cloudiness'], df['rain'], color='blue', marker='o', label='Data Points')

# Menambahkan judul dan label sumbu
plt.title('Scatter Plot Example')
plt.xlabel('cloudiness')
plt.ylabel('rain')

# Menambahkan legenda
plt.legend()

# Menampilkan plot
plt.show()

# %%
bins = int(np.ceil(np.log2(len(df['rain'])) + 1))


# Menambahkan judul dan label
plt.hist(df['rain'], bins=bins, edgecolor='black')
plt.title('Persebaran data rain')
plt.xlabel('rain')
plt.ylabel('Frekuensi')
# Menampilkan histogram
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_rain['rain'], orient='h')
plt.title('data rain')
plt.show()

# %%
df.loc[df['label'] == 'waspada'].min()
# Out:
# temperature                     22.47
# humidity                           52
# pressure                         1005
# wind_speed                       0.17
# wind_direction                      6
# rain                             0.46
# cloudiness                          4
# description                         4
# condition_type                      1
# timestamp         2024-10-28 16:09:08
# label                         waspada
# dtype: object

# %%
df.loc[df['label'] == 'bahaya'].min()
# Out:
# temperature                     22.42
# humidity                           68
# pressure                         1006
# wind_speed                       0.08
# wind_direction                     17
# rain                             1.02
# cloudiness                         15
# description                         6
# condition_type                      1
# timestamp         2024-10-31 04:09:09
# label                          bahaya
# dtype: object

# %% [markdown]
# # RAIN DATA

# %%
df_rain.describe()
# Out:
#        temperature    humidity     pressure  wind_speed  wind_direction  \
# count   289.000000  289.000000   289.000000  289.000000      289.000000
# mean     26.677924   85.723183  1008.788927    0.905813      172.761246
# std       3.176765   13.612425     1.720106    0.473229      100.648324
# min      22.420000   48.000000  1005.000000    0.060000        1.000000
# 25%      23.660000   75.000000  1007.000000    0.570000       93.000000
# 50%      26.150000   91.000000  1009.000000    0.840000      159.000000
# 75%      29.410000   97.000000  1010.000000    1.180000      243.000000
# max      34.200000  100.000000  1013.000000    2.360000      360.000000
#
#              rain  cloudiness  description  condition_type
# count  289.000000  289.000000   289.000000           289.0
# mean     0.685606   86.553633     4.477509             1.0
# std      0.573653   19.525217     0.854124             0.0
# min      0.100000    4.000000     4.000000             1.0
# 25%      0.230000   81.000000     4.000000             1.0
# 50%      0.520000   95.000000     4.000000             1.0
# 75%      0.970000  100.000000     4.000000             1.0
# max      2.890000  100.000000     6.000000             1.0

# %%
df_rain['description'].value_counts()
# Out:
# description
# 4    220
# 6     69
# Name: count, dtype: int64

# %%
df_rain.describe()
# Out:
#        temperature    humidity     pressure  wind_speed  wind_direction  \
# count   289.000000  289.000000   289.000000  289.000000      289.000000
# mean     26.677924   85.723183  1008.788927    0.905813      172.761246
# std       3.176765   13.612425     1.720106    0.473229      100.648324
# min      22.420000   48.000000  1005.000000    0.060000        1.000000
# 25%      23.660000   75.000000  1007.000000    0.570000       93.000000
# 50%      26.150000   91.000000  1009.000000    0.840000      159.000000
# 75%      29.410000   97.000000  1010.000000    1.180000      243.000000
# max      34.200000  100.000000  1013.000000    2.360000      360.000000
#
#              rain  cloudiness  description  condition_type
# count  289.000000  289.000000   289.000000           289.0
# mean     0.685606   86.553633     4.477509             1.0
# std      0.573653   19.525217     0.854124             0.0
# min      0.100000    4.000000     4.000000             1.0
# 25%      0.230000   81.000000     4.000000             1.0
# 50%      0.520000   95.000000     4.000000             1.0
# 75%      0.970000  100.000000     4.000000             1.0
# max      2.890000  100.000000     6.000000             1.0

# %%
df_rain.loc[df_rain['description'] == 4].describe()
# Out:
#        temperature    humidity     pressure  wind_speed  wind_direction  \
# count   220.000000  220.000000   220.000000  220.000000      220.000000
# mean     26.543091   85.477273  1008.859091    0.913409      171.595455
# std       3.309277   14.744535     1.760334    0.493838      102.129227
# min      22.470000   48.000000  1005.000000    0.060000        1.000000
# 25%      23.617500   72.750000  1008.000000    0.577500       93.250000
# 50%      25.225000   93.000000  1009.000000    0.845000      157.500000
# 75%      29.525000   97.000000  1010.000000    1.192500      240.500000
# max      34.200000   99.000000  1013.000000    2.360000      360.000000
#
#              rain  cloudiness  description  condition_type
# count  220.000000  220.000000        220.0           220.0
# mean     0.415364   85.318182          4.0             1.0
# std      0.251048   20.412384          0.0             0.0
# min      0.100000    4.000000          4.0             1.0
# 25%      0.190000   78.000000          4.0             1.0
# 50%      0.340000   95.000000          4.0             1.0
# 75%      0.620000  100.000000          4.0             1.0
# max      0.990000  100.000000          4.0             1.0

# %%
df_rain.loc[df_rain['description'] == 6].describe()
# Out:
#        temperature    humidity     pressure  wind_speed  wind_direction  \
# count    69.000000   69.000000    69.000000   69.000000       69.000000
# mean     27.107826   86.507246  1008.565217    0.881594      176.478261
# std       2.688098    9.154914     1.576279    0.402831       96.402894
# min      22.420000   68.000000  1006.000000    0.080000       17.000000
# 25%      24.290000   80.000000  1007.000000    0.560000       93.000000
# 50%      27.720000   87.000000  1009.000000    0.840000      184.000000
# 75%      29.230000   95.000000  1010.000000    1.170000      250.000000
# max      31.370000  100.000000  1012.000000    1.720000      357.000000
#
#             rain  cloudiness  description  condition_type
# count  69.000000   69.000000         69.0            69.0
# mean    1.547246   90.492754          6.0             1.0
# std     0.448491   15.876011          0.0             0.0
# min     1.020000   15.000000          6.0             1.0
# 25%     1.200000   89.000000          6.0             1.0
# 50%     1.440000   98.000000          6.0             1.0
# 75%     1.770000  100.000000          6.0             1.0
# max     2.890000  100.000000          6.0             1.0

# %% [markdown]
# # RAW DATA

# %%
df_raw['description'].unique()
# Out:
# array(['broken clouds', 'scattered clouds', 'few clouds',
#        'overcast clouds', 'light rain', 'clear sky', 'moderate rain'],
#       dtype=object)
